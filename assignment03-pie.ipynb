# %% [markdown]
# # assignment03-pie.ipynb
#
#
# ![pies]https://upload.wikimedia.org/wikipedia/commons/2/2c/Disk_usage_%28Boabab%29.png)
#
#
#
# #### This note book contains a nice pie chart of peoples email domains in the given csv file at the url.
#
# This csv file has 1000 people. You may download the data or link to it. It'll be downloaded.

# %%
# Libreries

# Data frames. 
import pandas as pd

# Plotting.
import matplotlib.pyplot as plt


import seaborn as sns

# Numerical arrays.
import numpy as np

# %%
# Loding data

df = pd.read_csv("https://drive.google.com/uc?id=1AWPf-pJodJKeHsARQK_RHiNsE8fjPCVK&export=download")

# %%
# The data is downloaded so we can inspect it
### source: https://drive.google.com/uc?id=1AWPf-pJodJKeHsARQK_RHiNsE8fjPCVK&export=download

df = df.drop(columns=['Index']) 


# Let's have a look.
df
# Out:
#              User Id First Name Last Name     Sex  \
# 0    8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1    3d5AD30A4cD38ed         Jo    Rivers  Female
# 2    810Ce0F276Badec     Sheryl    Lowery  Female
# 3    BF2a889C00f0cE1    Whitney    Hooper    Male
# 4    9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..               ...        ...       ...     ...
# 995  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997  2adde51d8B8979E      Cathy  Mckinney  Female
# 998  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# 2              fhoward@example.org          (599)782-0605    2013-11-25
# ...

# %%
# Lets have a look at top rows

df .head
# Out:
# <bound method NDFrame.head of              User Id First Name Last Name     Sex  \
# 0    8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1    3d5AD30A4cD38ed         Jo    Rivers  Female
# 2    810Ce0F276Badec     Sheryl    Lowery  Female
# 3    BF2a889C00f0cE1    Whitney    Hooper    Male
# 4    9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..               ...        ...       ...     ...
# 995  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997  2adde51d8B8979E      Cathy  Mckinney  Female
# 998  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# 2              fhoward@example.org          (599)782-0605    2013-11-25
# ...

# %%
# Lets have a look at the information about the columns

df .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User Id        1000 non-null   object
#  1   First Name     1000 non-null   object
#  2   Last Name      1000 non-null   object
#  3   Sex            1000 non-null   object
#  4   Email          1000 non-null   object
#  5   Phone          1000 non-null   object
#  6   Date of birth  1000 non-null   object
#  7   Job Title      1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
# Letas have a look at the statistical information
df .describe()
# Out:
#                 User Id First Name Last Name   Sex                Email  \
# count              1000       1000      1000  1000                 1000
# unique             1000        526       628     2                 1000
# top     8717bbf45cCDbEe      Lydia      Duke  Male  pwarner@example.org
# freq                  1          6         6   506                    1
#
#                Phone Date of birth         Job Title
# count           1000          1000              1000
# unique          1000           991               519
# top     857.139.8239    1955-07-31  Paediatric nurse
# freq               1             2                 7

# %%
# Making pie charts

# Labels

labels = 'User Id', 'First Name', 'Last Name', 'Sex', 'Emal', 'Phone', 'Date of Birth', 'Job Title'

sizes = [20,10,10,10,10,10,20,10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e6c5973770>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'User Id'),
#   Text(-2.5747358111484753e-08, 1.0999999999999999, 'First Name'),
#   Text(-0.6465638066837905, 0.8899186726249574, 'Last Name'),
#   Text(-1.0461621822461362, 0.3399186497354952, 'Sex'),
#   Text(-1.0461621504206509, -0.33991874768426583, 'Emal'),
#   Text(-0.6465637233635886, -0.8899187331606258, 'Phone'),
#   Text(0.33991877217145827, -1.046162142464278, 'Date of Birth'),
#   Text(1.0461621981588753, -0.33991860076110864, 'Job Title')])

# %%
# Auto-label slices

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e6c3c14410>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'User Id'),
#   Text(-2.5747358111484753e-08, 1.0999999999999999, 'First Name'),
#   Text(-0.6465638066837905, 0.8899186726249574, 'Last Name'),
#   Text(-1.0461621822461362, 0.3399186497354952, 'Sex'),
#   Text(-1.0461621504206509, -0.33991874768426583, 'Emal'),
#   Text(-0.6465637233635886, -0.8899187331606258, 'Phone'),
#   Text(0.33991877217145827, -1.046162142464278, 'Date of Birth'),
#   Text(1.0461621981588753, -0.33991860076110864, 'Job Title')],
#  [Text(0.4854101933230228, 0.35267115592022213, '20.0%'),
#   Text(-1.4044013515355319e-08, 0.5999999999999999, '10.0%'),
#   Text(-0.35267116728206754, 0.48541018506815853, '10.0%'),
#   Text(-0.5706339175888016, 0.18541017258299736, '10.0%'),
#   Text(-0.5706339002294459, -0.18541022600959953, '10.0%'),
#   Text(-0.3526711218346847, -0.485410218087614, '10.0%'),
#   Text(0.18541023936624995, -0.5706338958896061, '20.0%'),
# ...

# %%
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels,
       colors=['olivedrab', 'rosybrown', 'gray', 'saddlebrown', 'chocolate', 'tan', 'darkolivegreen', 'g'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1e6c8ab2180>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'User Id'),
#   Text(-2.5747358111484753e-08, 1.0999999999999999, 'First Name'),
#   Text(-0.6465638066837905, 0.8899186726249574, 'Last Name'),
#   Text(-1.0461621822461362, 0.3399186497354952, 'Sex'),
#   Text(-1.0461621504206509, -0.33991874768426583, 'Emal'),
#   Text(-0.6465637233635886, -0.8899187331606258, 'Phone'),
#   Text(0.33991877217145827, -1.046162142464278, 'Date of Birth'),
#   Text(1.0461621981588753, -0.33991860076110864, 'Job Title')])

# %%
# Hatch slices

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, hatch=['**O', 'oO', 'O.O', '.||.', '**', '*#'])
# Out:
# C:\Users\hugoc\AppData\Local\Temp\ipykernel_1780\2624515172.py:4: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "#". Passing invalid values is deprecated since 3.4 and will become an error in 3.9.
#   ax.pie(sizes, labels=labels, hatch=['**O', 'oO', 'O.O', '.||.', '**', '*#'])
# ([<matplotlib.patches.Wedge at 0x1e6c623f200>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'User Id'),
#   Text(-2.5747358111484753e-08, 1.0999999999999999, 'First Name'),
#   Text(-0.6465638066837905, 0.8899186726249574, 'Last Name'),
#   Text(-1.0461621822461362, 0.3399186497354952, 'Sex'),
#   Text(-1.0461621504206509, -0.33991874768426583, 'Emal'),
#   Text(-0.6465637233635886, -0.8899187331606258, 'Phone'),
#   Text(0.33991877217145827, -1.046162142464278, 'Date of Birth'),
#   Text(1.0461621981588753, -0.33991860076110864, 'Job Title')])

# %%
# staff sex

uniqueInstances = df['Sex'].value_counts()
maleCount = uniqueInstances.iloc[0]
femaleCount = uniqueInstances.iloc[1]

print("Male Count: ", maleCount)
print("Female Count: ", femaleCount)
# Out:
# Male Count:  506
# Female Count:  494

# %%
# Gender distribution
# Create a pie chart using the counts of Male and Female
labels = ['Male', 'Female']
sizes = [maleCount, femaleCount]
colors = ['lightblue', 'lightcoral']

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, explode=(0.1, 0), shadow=True)
plt.title('Gender Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the plot
plt.show()
