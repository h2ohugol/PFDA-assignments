# %% [markdown]
# # assignment2-weather.ipynb
#
# ****

# %% [markdown]
# ![from media.istockphoto](https://media.istockphoto.com/id/1391715814/vector/forecast-weather-isobar-map-usa-state-meteorology.jpg?s=612x612&w=0&k=20&c=CuEEjUuZBQep94KGSfk-ZKZ16vTOxI2ktZfngkrAcyg=)
#
#
# This notebook content is on weather information.
#
# The dataset is available on [Github](https://github.com/andrewbeattycourseware/PFDA-courseware/blob/main/assignment/weatherreadings1.csv)

# %% [markdown]
# ## Libraries
#
# ***

# %% [markdown]
# We use pandas for the dataFrame data structure.
#
# It allows to investigate [CSV](https://pandas.pydata.org/docs/user_guide/10min.html) files, amongst other features.
#
# [matplotlib](https://www.w3schools.com/python/matplotlib_pyplot.asp) is theplotting library in python that serves as a
# visualization utility.
#
# [NumPy](https://www.w3schools.com/python/numpy/default.asp) to help us working with arrays.

# %%
# Data frames. 
import pandas as pd

# Plotting.
import matplotlib.pyplot as plt

# Numerical arrays.
import numpy as np

# %% [markdown]
# ### Load data
#
# ***
#
# #### Load the weather data from URL.

# %%
# Load the weather data

df = pd.read_csv("https://raw.githubusercontent.com/andrewbeattycourseware/PFDA-courseware/refs/heads/main/assignment/weatherreadings1.csv")

# %% [markdown]
# ### The data is loaded so we can inspect it

# %%
# drops all NaN instances.
# source: https://stackoverflow.com/questions/44548721/remove-row-with-null-value-from-pandas-data-frame
df = df.dropna(how='any',axis=0) 

# Let's have a look.
df
# Out:
#                                   siteId        reportStartDateTime  \
# 0   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# 1   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# 2   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# 3   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# 4   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
# ..                                   ...                        ...
# 84  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:00:00+00:00
# 85  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:15:00+00:00
# 86  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:30:00+00:00
# 87  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:45:00+00:00
# 88  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T15:00:00+00:00
#
#             reportEndDateTime  collectionName  isPublic  isLatestVersion  \
# 0   2024-10-02T16:15:00+00:00               1      True             True
# ...
